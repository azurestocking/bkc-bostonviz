# %%
# Load libraries
import pandas as pd
import textwrap

# %% [markdown]
# Dataset: BOSTON BUILDINGS INVENTORY
#
# Source: https://data.boston.gov/dataset/boston-buildings-inventory
#
# Description:
# This dataset pulls from many different data sources to identify individual building characteristics of all buildings in Boston. It also identifies high-potential retrofit options to reduce carbon emissions in multifamily buildings, using the best available data and assumptions from building experts.

# %%
# Load main datafile: BOSTON BUILDING INVENTORY
df = pd.read_csv("building_inventory_021020.csv")
df.head()
# Out:
# C:\Users\JustinMingganWei\AppData\Local\Temp\ipykernel_10672\3769625082.py:2: DtypeWarning: Columns (1,40,44,47,51,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("building_inventory_021020.csv")
#       id    pid_long  cm_id    building_typology  \
# 0  88905         NaN    NaN                  NaN
# 1  51137  1600083000    NaN        Single-Family
# 2  18045   202560000    NaN        Single-Family
# 3  94001  2200577000    NaN  Convention/Assembly
# 4  92940  1600058000    NaN                  NaN
#
#              building_subtypology              use_class     sqft_class  \
# 0                             NaN                    NaN            NaN
# 1        Single-Family, 1915-1949            Residential  < 25,000 sqft
# 2         Single-Family, Pre-1915            Residential  < 25,000 sqft
# 3  Convention/Assembly, 1950-1979  Public & Quasi-Public  < 25,000 sqft
# ...

# %%
print("This dataset contains", df.shape[0], "entries building information, with", df.shape[1], "attributes for each.")
# Out:
# This dataset contains 98930 entries building information, with 107 attributes for each.

# %%
columns_str = ', '.join(df.columns.tolist())
wrapped_columns = textwrap.fill(columns_str, width=128)
print("Here is a full list of all the columns / attributes:\n\n"+wrapped_columns)
# Out:
# Here is a full list of all the columns / attributes:
#
# id, pid_long, cm_id, building_typology, building_subtypology, use_class, sqft_class, year_built_class, st_num, st_name,
# st_name_suf, unit_num, zipcode, yr_built, land_sf, gross_area, living_area, sqft, num_floors, num_bldgs, units_res, units_com,
# units_mixed, ptype, ptype_list, lu, lu_list, assessor_category, assessor_description, own_occ, own_occ_list, owner_list,
# structure_class, structure_class_list, bldg_styl, bldg_styl_list, r_roof_typ, ext_fin, ext_fin_list, ext_cond_list,
# insulation_type, foundation_type, heat_typ, heat_typ_list, heating_system_fuel, ac, ac_list, ac_system_type,
# hot_water_system_fuel, electric_panel_info, has_pv, existing_ashp, existing_gshp, existing_shw, historic_district, landmark,
# flood, stormwater, last_major_renovation_date, total_site_energy_kbtu, perc_electricity, perc_gas, perc_steam,
# ...

# %%
df_description = pd.read_csv("fields-definitions.csv")
df_description['Field Name'] = df_description['Field Name'].str.strip() # Cleansing for extra spaces
df_cat = df_description.Category.unique()
print("Main", len(df_cat), "attribute categories:\n\n", df_cat)
# Out:
# Main 13 attribute categories:
#
#  ['General information' 'Uses' 'Other' 'Building age' 'Building size'
#  'Height' 'Number of buildings' 'Number of units' 'Zoning' 'Socioeconomic'
#  'Environmental' 'Heat Pump Strategy' 'Envelope Strategy']

# %% [markdown]
# With the supplementary data fields descriptions file, we see that there are 13 main categories of attributes. We can use this to group the 107 attributes into smaller groups for easier operations.

# %% [markdown]
# The dataset contains all buildings in Boston, but we are only interested in those that are landmarks:

# %%
filtered_df = df[df['landmark'] == 't']
print("Number of all landmarks:", len(filtered_df))
# Out:
# Number of all landmarks: 632

# %% [markdown]
# Check if there is anything be of our interests in the `Uses` attributes:

# %%
df_description[df_description.Category == "Uses"][["Field Name", "Description"]]
# Out:
#               Field Name                                        Description
# 8                  ptype                                 Property type code
# 9             ptype_list  List of property type codes (where data was ag...
# 10                    lu                                      Land use code
# 11               lu_list  List of land use codes (where data was aggrega...
# 12               own_occ  Whether the property receives a tax exemption ...
# 13          own_occ_list  List of owner occupany types (where data was a...
# 37     assessor_category       Property type category associated with ptype
# 38  assessor_description    Property type description associated with ptype
# 76             use_class                         General use classification
# 79     building_typology           General building typology classification
# 80  building_subtypology  Building typology classification including sub...

# %%
filtered_df[df_description[df_description.Category == "Uses"]["Field Name"].tolist()].head()
# Out:
#      ptype ptype_list  lu lu_list own_occ own_occ_list     assessor_category  \
# 3    941.0        941   E       E       N            N  Exempt Property Type
# 71   986.0        986   E       E       N            N  Exempt Property Type
# 112  102.0    102,995  CD   CD,CM       N          N,Y  Residential Property
# 124  995.0        995  CM      CM       N            N  Exempt Property Type
# 129  995.0        995  CM      CM       N            N  Exempt Property Type
#
#      assessor_description                use_class  \
# 3    Auditorium / Theater    Public & Quasi-Public
# 71            Vacant Land                   Vacant
# 112     Residential Condo              Residential
# 124            Condo Main  Residential (Mixed-Use)
# 129            Condo Main              Residential
#
#                building_typology                       building_subtypology
# 3            Convention/Assembly             Convention/Assembly, 1950-1979
# ...

# %% [markdown]
# We want to look at what are the `General Use Classification` of these landmarks:

# %%
filtered_df.groupby('use_class').size().sort_values(ascending=False)
# Out:
# use_class
# Residential                209
# Public & Quasi-Public      198
# Commercial                 155
# Vacant                      35
# Residential (Mixed-Use)     34
# Industrial                   1
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="color: #333; background-color: #e6e6fa; border-color: #d8bfd8; border-width: 1px; border-radius: 3px; padding: 10px;">
#
# **⭐ Findings:**
# - 33% of the landmarks are `Residential`, 31% are `Public & Quasi-Public`, 25% are `Commercial`.
#
# </div>

# %% [markdown]
# Fixing defective entry of `Field Name` in the fields descriptions dataset:
# >`KeyError: "['perc_gas numeric'] not in index"`

# %%
df_description.loc[df_description['Field Name'] == 'perc_gas numeric', 'Field Name'] = 'perc_gas'

# %% [markdown]
# **Data Cleansing**
#
# Checking for missing data by attribute categories:

# %% [markdown]
# >'General information' 'Uses' 'Other' 'Building age' 'Building size'
#  'Height' 'Number of buildings' 'Number of units' 'Zoning' 'Socioeconomic'
#  'Environmental' 'Heat Pump Strategy' 'Envelope Strategy'

# %%
# for cat in df_cat:
#    filtered_df[df_description[df_description.Category == cat]["Field Name"].tolist()].info(verbose=True, show_counts=True)

# %%
df_description[df_description.Category == "General information"][["Field Name", "Description"]]
# Out:
#      Field Name              Description
# 0            id                Unique ID
# 1      pid_long                Parcel ID
# 2         cm_id            Condo Main ID
# 3        st_num            Street number
# 4       st_name              Street name
# 5   st_name_suf       Street name suffix
# 6      unit_num      Address unit number
# 7       zipcode                 Zip code
# 14   owner_list  List of property owners

# %%
filtered_df[df_description[df_description.Category == 'General information']["Field Name"].tolist()].isnull().sum()
# Out:
# id               0
# pid_long         0
# cm_id          544
# st_num          88
# st_name         88
# st_name_suf     88
# unit_num       632
# zipcode         88
# owner_list       0
# dtype: int64

# %%
df_description[df_description.Category == "Uses"][["Field Name", "Description"]]
# Out:
#               Field Name                                        Description
# 8                  ptype                                 Property type code
# 9             ptype_list  List of property type codes (where data was ag...
# 10                    lu                                      Land use code
# 11               lu_list  List of land use codes (where data was aggrega...
# 12               own_occ  Whether the property receives a tax exemption ...
# 13          own_occ_list  List of owner occupany types (where data was a...
# 37     assessor_category       Property type category associated with ptype
# 38  assessor_description    Property type description associated with ptype
# 76             use_class                         General use classification
# 79     building_typology           General building typology classification
# 80  building_subtypology  Building typology classification including sub...

# %%
filtered_df[df_description[df_description.Category == 'Uses']["Field Name"].tolist()].isnull().sum()
# Out:
# ptype                     0
# ptype_list                0
# lu                        0
# lu_list                   0
# own_occ                   0
# own_occ_list              0
# assessor_category         0
# assessor_description      0
# use_class                 0
# building_typology       110
# building_subtypology    175
# dtype: int64

# %%
df_description[df_description.Category == "Other"][["Field Name", "Description"]]
# Out:
#                     Field Name  \
# 15                     land_sf
# 21             structure_class
# 22        structure_class_list
# 23                   bldg_styl
# 24              bldg_styl_list
# 25                  r_roof_typ
# 26                     ext_fin
# 27                ext_fin_list
# 28                    heat_typ
# 29               heat_typ_list
# 30                          ac
# 31                     ac_list
# 32               ext_cond_list
# 41                      has_pv
# 42  last_major_renovation_date
# 43         heating_system_fuel
# 44              ac_system_type
# 45       hot_water_system_fuel
# 46             insulation_type
# 47             foundation_type
# 48         electric_panel_info
# 49               existing_ashp
# 50               existing_gshp
# 51                existing_shw
# 52      total_site_energy_kbtu
# 53            perc_electricity
# 54                    perc_gas
# 55                  perc_steam
# 56        onsite_renewable_kwh
#
# ...

# %%
filtered_df[df_description[df_description.Category == 'Other']["Field Name"].tolist()].isnull().sum()
# Out:
# land_sf                         0
# structure_class               181
# structure_class_list          181
# bldg_styl                     466
# bldg_styl_list                466
# r_roof_typ                    469
# ext_fin                       466
# ext_fin_list                  466
# heat_typ                      473
# heat_typ_list                 476
# ac                            476
# ac_list                       476
# ext_cond_list                 466
# has_pv                        622
# last_major_renovation_date    352
# heating_system_fuel           632
# ac_system_type                632
# hot_water_system_fuel         631
# insulation_type               632
# foundation_type               631
# electric_panel_info           631
# existing_ashp                 632
# existing_gshp                 632
# existing_shw                  632
# total_site_energy_kbtu        562
# perc_electricity              562
# perc_gas                      576
# ...

# %%
df_description[df_description.Category == "Building age"][["Field Name", "Description"]]
# Out:
#           Field Name                  Description
# 16          yr_built                   Year built
# 78  year_built_class  Building age classification

# %%
filtered_df[df_description[df_description.Category == 'Building age']["Field Name"].tolist()].isnull().sum()
# Out:
# yr_built            140
# year_built_class    140
# dtype: int64

# %%
df_description[df_description.Category == "Building size"][["Field Name", "Description"]]
# Out:
#      Field Name                                        Description
# 17   gross_area  Building area for commercial parcels (square f...
# 18  living_area  Building living area for residential parcels (...
# 19         sqft                        Building area (square feet)
# 77   sqft_class  Square footage classification based on sqft field

# %%
filtered_df[df_description[df_description.Category == 'Building size']["Field Name"].tolist()].isnull().sum()
# Out:
# gross_area      19
# living_area     19
# sqft           105
# sqft_class     136
# dtype: int64

# %%
df_description[df_description.Category == "Height"][["Field Name", "Description"]]
# Out:
#     Field Name       Description
# 20  num_floors  Number of floors

# %%
filtered_df[df_description[df_description.Category == 'Height']["Field Name"].tolist()].isnull().sum()
# Out:
# num_floors    125
# dtype: int64

# %%
df_description[df_description.Category == "Number of buildings"][["Field Name", "Description"]]
# Out:
#    Field Name          Description
# 33  num_bldgs  Number of buildings

# %%
filtered_df[df_description[df_description.Category == 'Number of buildings']["Field Name"].tolist()].isnull().sum()
# Out:
# num_bldgs    41
# dtype: int64

# %%
df_description[df_description.Category == "Number of units"][["Field Name", "Description"]]
# Out:
#      Field Name                  Description
# 34    units_res  Number of residential units
# 35    units_com   Number of commercial units
# 36  units_mixed    Number of mixed-use units

# %%
filtered_df[df_description[df_description.Category == 'Number of units']["Field Name"].tolist()].isnull().sum()
# Out:
# units_res      418
# units_com      540
# units_mixed    544
# dtype: int64

# %%
df_description[df_description.Category == "Zoning"][["Field Name", "Description"]]
# Out:
#            Field Name                                     Description
# 39  historic_district  Whether the property is in a historic district
# 40           landmark  Whether the property is in a landmark district

# %%
filtered_df[df_description[df_description.Category == 'Zoning']["Field Name"].tolist()].isnull().sum()
# Out:
# historic_district    0
# landmark             0
# dtype: int64

# %%
df_description[df_description.Category == "Socioeconomic"][["Field Name", "Description"]]
# Out:
#                              Field Name  \
# 57                  census_tract_number
# 58                    ct_pop_disability
# 59              ct_pop_children_under_5
# 60                       ct_pop_over_65
# 61              ct_pop_low_to_no_income
# 62   ct_pop_limited_english_proficiency
# 63                           ct_pop_poc
# 64                   ct_pop_med_illness
# 65                   ct_perc_disability
# 66             ct_perc_children_under_5
# 67                      ct_perc_over_65
# 68             ct_perc_low_to_no_income
# 69  ct_perc_limited_english_proficiency
# 70                          ct_perc_poc
# 71                  ct_perc_med_illness
# 72          ct_hh_income_200000_or_more
# 73        ct_perc_income_200000_or_more
#
#                                           Description
# 57                                Census Tract number
# 58  Population in Census Tract of people with disa...
# 59       Population in Census Tract under 5 years old
# ...

# %%
filtered_df[df_description[df_description.Category == 'Socioeconomic']["Field Name"].tolist()].isnull().sum()
# Out:
# census_tract_number                    12
# ct_pop_disability                      12
# ct_pop_children_under_5                12
# ct_pop_over_65                         12
# ct_pop_low_to_no_income                12
# ct_pop_limited_english_proficiency     12
# ct_pop_poc                             12
# ct_pop_med_illness                     12
# ct_perc_disability                     12
# ct_perc_children_under_5               12
# ct_perc_over_65                        12
# ct_perc_low_to_no_income               12
# ct_perc_limited_english_proficiency    12
# ct_perc_poc                            12
# ct_perc_med_illness                    12
# ct_hh_income_200000_or_more            20
# ct_perc_income_200000_or_more          20
# dtype: int64

# %%
df_description[df_description.Category == "Environmental"][["Field Name", "Description"]]
# Out:
#     Field Name                                        Description
# 74       flood  Whether the property falls within the 1% annua...
# 75  stormwater  Whether the property falls within the stormwat...

# %%
filtered_df[df_description[df_description.Category == 'Environmental']["Field Name"].tolist()].isnull().sum()
# Out:
# flood         0
# stormwater    0
# dtype: int64

# %%
df_description[df_description.Category == "Heat Pump Strategy"][["Field Name", "Description"]]
# Out:
#                  Field Name                                        Description
# 81               cashp_only  Whether ducted (central) air source heat pump ...
# 82   cashp_and_elec_upgrade  Whether ducted (central) air source heat pump ...
# 83            cashp_outdoor  Whether ducted (central) air source heat pump ...
# 84               dashp_only  Whether ductless air source heat pump replacem...
# 85   dashp_and_elec_upgrade  Whether ductless air source heat pump replacem...
# 86            dashp_outdoor  Whether ductless air source heat pump replacem...
# 87                gshp_only  Whether ground source heat pump replacement or...
# 88    gshp_and_elec_upgrade  Whether ground source heat pump replacement or...
# 89                 vrf_only  Whether variable refrigerant flow replacement ...
# 90     vrf_and_elec_upgrade  Whether variable refrigerant flow replacement ...
# 91                awhp_only  Whether air-to-water heat pump replacement or ...
# ...

# %%
filtered_df[df_description[df_description.Category == 'Heat Pump Strategy']["Field Name"].tolist()].isnull().sum()
# Out:
# cashp_only                 0
# cashp_and_elec_upgrade     0
# cashp_outdoor              0
# dashp_only                 0
# dashp_and_elec_upgrade     0
# dashp_outdoor              0
# gshp_only                  0
# gshp_and_elec_upgrade      0
# vrf_only                   0
# vrf_and_elec_upgrade       0
# awhp_only                  0
# awhp_and_elec_upgrade      0
# hp_recommendation_count    0
# dtype: int64

# %%
df_description[df_description.Category == "Envelope Strategy"][["Field Name", "Description"]]
# Out:
#                                   Field Name  \
# 94                            insulate_attic
# 95                  insulate_attic_converted
# 96                       ext_roof_insulation
# 97                    insulate_exposed_ducts
# 98                    insulate_exposed_pipes
# 99          interior_wall_insulation_blow_in
# 100  exterior_wall_insulation_at_replacement
# 101                 exterior_wall_insulation
# 102           interior_wall_insulation_board
# 103                        insulate_spandrel
# 104                                 asbestos
# 105                seal_elevator_vent_shafts
# 106                 env_recommendation_count
#
#                                            Description
# 94             Whether attic insulation is recommended
# 95   Whether insulation is recommended in a convert...
# 96     Whether exterior roof insulation is recommended
# 97     Whether insulating exposed ducts is recommended
# ...

# %%
filtered_df[df_description[df_description.Category == 'Envelope Strategy']["Field Name"].tolist()].isnull().sum()
# Out:
# insulate_attic                             0
# insulate_attic_converted                   0
# ext_roof_insulation                        0
# insulate_exposed_ducts                     0
# insulate_exposed_pipes                     0
# interior_wall_insulation_blow_in           0
# exterior_wall_insulation_at_replacement    0
# exterior_wall_insulation                   0
# interior_wall_insulation_board             0
# insulate_spandrel                          0
# asbestos                                   0
# seal_elevator_vent_shafts                  0
# env_recommendation_count                   0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="color: #333; background-color: #e6e6fa; border-color: #d8bfd8; border-width: 1px; border-radius: 3px; padding: 10px;">
#
# **⭐ Findings:**
# - In `General Information` category, we will rely on `st_num`, `st_name`, and `zipcode` in order to locate the respective building on a map. There are 88 entries that are missing the street address information, so we will drop those entries.
# - In `Uses` category, there are over 100 entries has missing values in `building_typology` and `building_subtypology`, which are the "General building typology classification" and "Building typology classification including subtypology based on building age". We have not decided what to do with this pair of features, so we are keeping these entries for now.
# - In `Other` category, only `land_sf` has no missing data; all other attributes have great missingness and are mostly unuseable. We may consider only keeping the "Land area of parcel (square feet)" and dropping all other columns.
# - in `Building age` category, `yr_built` is a key attribute we will be using for our visualization. There are 140 entries are missing "Year built" so we will have to drop those entries.
# - in `Building size`, `Height`, `Number of buildings`, `Number of units` categories, there are a few entries missing `sqft`, `sqft_class`, `num_floors`, `num_bldgs`, `units_res`, `units_com`, `units_mixed`. We will keep these for now as we continue exploring.
# - in `Socioeconomic` category, all attributes are related to Census Tract, we will set them aside for now as we continue exploring.
#
# </div>

# %% [markdown]
# Now dropping select entries with missing data:

# %%
cols_to_scan = ['st_num', 'st_name', 'zipcode', 'yr_built']
cols_to_drop = ['bldg_styl',
 'bldg_styl_list',
 'r_roof_typ',
 'ext_fin',
 'ext_fin_list',
 'heat_typ',
 'heat_typ_list',
 'ac',
 'ac_list',
 'ext_cond_list',
 'has_pv',
 'last_major_renovation_date',
 'heating_system_fuel',
 'ac_system_type',
 'hot_water_system_fuel',
 'insulation_type',
 'foundation_type',
 'electric_panel_info',
 'existing_ashp',
 'existing_gshp',
 'existing_shw',
 'total_site_energy_kbtu',
 'perc_electricity',
 'perc_gas',
 'perc_steam',
 'onsite_renewable_kwh']

# %%
filtered_df = filtered_df.drop(columns=cols_to_drop)

# %%
cleaned_filtered_df = filtered_df.dropna(subset=cols_to_scan, how='any')
cleaned_filtered_df = cleaned_filtered_df.drop(columns=df_description[df_description.Category == 'Socioeconomic']["Field Name"].tolist())

# %% [markdown]
# Dataset overview after cleansing:

# %%
cleaned_filtered_df.describe()
# Out:
#                  id  cm_id  unit_num      zipcode     yr_built       land_sf  \
# count    404.000000    0.0       0.0   404.000000   404.000000  4.040000e+02
# mean   53269.274752    NaN       NaN  2132.534653  1917.596535  8.639063e+04
# std    29931.118523    NaN       NaN    37.440325    31.783356  5.091808e+05
# min        7.000000    NaN       NaN  2108.000000  1845.000000  0.000000e+00
# 25%    25174.250000    NaN       NaN  2111.000000  1899.000000  4.006000e+03
# 50%    60248.500000    NaN       NaN  2119.000000  1906.000000  9.548500e+03
# 75%    78442.750000    NaN       NaN  2130.000000  1925.000000  2.535450e+04
# max    98792.000000    NaN       NaN  2467.000000  2018.000000  7.397130e+06
#
#          gross_area   living_area          sqft  num_floors  num_bldgs  \
# count  4.040000e+02  4.040000e+02  4.040000e+02  402.000000      404.0
# mean   7.636403e+04  6.616423e+04  7.486486e+04    4.889303        1.0
# ...

# %% [markdown]
# <div class="alert alert-success" style="color: #333; background-color: #e6e6fa; border-color: #d8bfd8; border-width: 1px; border-radius: 3px; padding: 10px;">
#
# **⭐ Findings:**
# - For `yr_built`, the oldest landmark was built in 1845 (almost 200 years ago!); the newest landmark was built in 2018.
# - For `land_sf`, the largest landmark sits on a land of 7397130 sqft, that's 170 acres! The largest `sqft`, the actual square footage is 1502842 sqft, that's 34.5 acres.
# - The tallest landmarks has 42 floors according to `num_floors`.
#
# </div>

# %% [markdown]
# **Getting Building Geographic Coordinate**
#
# In order to be able to plot these landmarks buildings accurately on map, we need to use their corrosponding longitude and latitude coordinates. The dataset doesn't come with buildings' coordinates, so we will have to get the coordinates based on their street addresses.

# %% [markdown]
# <div class="alert alert-success" style="color: #333; background-color: #e6e6fa; border-color: #d8bfd8; border-width: 1px; border-radius: 3px; padding: 10px;">
#
# **⭐ Next Steps:**
# - We will need find a way to get geographic coordinated for all landmarks. There should be related dataset or API we can utilize from the City of Boston. Worst case scenario, we will use street address to inference respective coordinates.
#
# </div>
